# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':(6,4)})

# %%
data = pd.read_csv("../Dataset/winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.shape
# Out:
# (1599, 12)

# %%
# plt.figure(figsize = (12,6))
# sns.countplot(x = data["quality"])
sns.countplot(data=data, x="quality") # , hue="fixed acidity"
plt.title('Countplot for Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
sns.barplot(data=data, x="quality", y="alcohol")
plt.title('Barplot for Quality vs. Alcohol')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

# %%
sns.scatterplot(data=data, x="citric acid", y="pH")
plt.title('Scatterplot for Citric acid vs. pH')
plt.xlabel('Citric acid')
plt.ylabel('pH')
plt.show()
